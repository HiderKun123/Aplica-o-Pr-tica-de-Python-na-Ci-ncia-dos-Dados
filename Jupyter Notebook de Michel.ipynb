# %% [markdown]
# # Jupyter notebook_Michel Chagas
# Estou achando a atividade muito interessante por estar descobrindo novas ferramentas.

# %%
import pandas as pd

# %%
## Para carregar o arquivo garantindo que as vírgulas separem as colunas

# %%
df = pd.read_csv('dados_clientes.csv', sep=',')

# %%
## Para saber quantas colunas os dados contêm:

# %%
print(df.shape[1])
# Out:
# 25

# %%
# Quantidade de linhas (amostras):

# %%
print(df.shape[0])
# Out:
# 30000

# %%
## Aqui eu fiz uma reparação nas colunas, pois não estava demarcado com aspas o nome delas, levando o panda a entender que só tinha uma coluna com um nome enorme:

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default payment next month']

# %%
import pandas as pd

# %%
df = pd.read_csv('dados_clientes.csv', sep=',')

# %%
print(f"Colunas encontradas: {df.shape[1]}")
print(df.columns.tolist())
# Out:
# Colunas encontradas: 25
# ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default payment next month']

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
##combinação da análise de tipos (dtypes) com a descrição estatística (describe) confirma que o dataset está higienizado (sem valores nulos aparentes) e pronto para a fase de pré-processamento

# %%
df[['LIMIT_BAL', 'AGE', 'BILL_AMT1']].describe()
# Out:
#             LIMIT_BAL           AGE      BILL_AMT1
# count    30000.000000  30000.000000   30000.000000
# mean    165760.989333     35.108800   50646.744233
# std     130158.590432      9.851592   73376.695080
# min          0.000000      0.000000 -165580.000000
# 25%      50000.000000     28.000000    3234.000000
# 50%     140000.000000     34.000000   21644.500000
# 75%     240000.000000     41.000000   66148.500000
# max    1000000.000000     79.000000  964511.000000

# %%
## Apareência das Categóricas (Frequências):

# %%
print(df['EDUCATION'].value_counts())
# Out:
# EDUCATION
# 2    13884
# 1    10474
# 3     4867
# 0      329
# 5      275
# 4      122
# 6       49
# Name: count, dtype: int64

# %%
print(df['SEX'].value_counts())
# Out:
# SEX
# 2    17910
# 1    11775
# 0      315
# Name: count, dtype: int64

# %%
## Verificando valores nulos (NaN): Se forem 0, está completo (não há dados faltando), se aparecer algum número maior que 0, significa que possui valores faltantes.

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
